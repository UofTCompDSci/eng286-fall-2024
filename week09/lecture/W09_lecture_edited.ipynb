# %% [markdown]
# # Week 9: A Pandas Approach to TTRs in the Colonial South Asian Literature dataset
#
#
# Having learned how to work with **metadata** in Pandas over the previous two weeks — we didn't look at any actual *text* of literary works; just at data **about** texts — this week we learn how to record findings about textual data in Pandas: by storing it in dataframes (and how to turn lists into dataframes, and to merge those lists). Our example of textual analysis is a familiar one: TTRs.
#
# Then we combine the two approaches. We load the Colonial South Asian Literature (CSAL) dataset (metadata), and then analyze each text represented in the metadata, calculating its overall and standardized TTR. We record these values, then merge them with a dataframe containing the CSAL metadata.
#
# Then we use Pandas to sort, process, and visualize our data, asking whether South Asian or foreign writers had notably divergent TTRs for their discussions of South Asia.

# %% [markdown]
# # Loading the CSAL Dataset
#
# Let's begin by loading the CSAL dataset and having a look at what kinds of "metadata" it contains.

# %%
import pandas as pd

# %%
csal_meta_df = pd.read_csv('csal.csv')

# %%
csal_meta_df
# Out:
#                                                   Text  \
# 0    W-D-Arnold-Oakfield-or-Fellowship-in-the-East-...
# 1    F-W-Bain-Digit-of-the-Moon-A-Hindoo-Love-Story...
# 2             S-B-Banerjea-Tales-of-Bengal-Fiction.txt
# 3         Edmund-Candler-The-Sepoy-1919-Nonfiction.txt
# 4           Edmund-Candler-Abdication-1922-fiction.txt
# ..                                                 ...
# 105  Collected-Poems-of-Henry-Derozio-Downloadable.txt
# 106  Peary-Chand-Mitter-A-Biographical-Sketch-of-Da...
# 107  Peary-Chand-Mitter-The-Spoilt-Child-A-Tale-of-...
# 108  Flora-Annie-Steel-The-Flower-of-Forgiveness-18...
# 109   Arthur-Conan-Doyle-The-Sign-of-the-Four-1890.txt
#
#                          Author  \
# 0      William Delafield Arnold
# 1          Francis William Bain
# 2                 S.B. Banerjea
# 3                Edmund Candler
# 4                Edmund Candler
# ..                          ...
# 105  Henry Louis Vivian Derozio
# 106           Peary Chand Mitra
# 107           Peary Chand Mitra
# 108           Flora Annie Steel
# 109          Arthur Conan Doyle
#
#                                                  Title  Year  \
# 0                 Oakfield; Or, Fellowship in the East  1855
# 1                                  A Hindoo Love Story  1898
# 2                                      Tales of Bengal  1910
# 3                                            The Sepoy  1919
# 4                                           Abdication  1922
# ..                                                 ...   ...
# 105                                    Collected Poems  1828
# 106                A Biographical Sketch of David Hare  1877
# 107  The Spoilt Child (translation of Alaler Gharer...  1893
# 108                          The Flower of Forgiveness  1894
# 109                               The Sign of the Four  1890
#
#      Original (if translated)       Genre          Publisher Location  \
# 0                         NaN     Fiction                   Cambridge
# 1                         NaN     Fiction                      London
# 2                         NaN     Fiction  New York, Bombay, Calcutta
# 3                         NaN     Fiction                      London
# 4                         NaN     Fiction              London, Bombay
# ..                        ...         ...                         ...
# 105                       NaN      Poetry                    Calcutta
# 106                       NaN  Nonfiction                    Calcutta
# 107                    1857.0     Fiction                    Calcutta
# 108                       NaN     Fiction            London, New York
# 109                       NaN     Fiction        London, Philadelphia
#
#                                       Publisher Name Nationality of Author  \
# 0    Metcalf and Company, Printers to the University               British
# 1                                 Methuen & Co. Ltd.               British
# 2                           Longmans, Green, and Co.           South Asian
# 3                                        John Murray               British
# 4                                    Constable & Co.               British
# ..                                               ...                   ...
# 105                             Samuel Smith and Co.           South Asian
# 106                                W. Newman and Co.           South Asian
# 107                           Thacker, Spink and Co.           South Asian
# 108                                Macmillan and Co.               British
# 109                    Lippincott's Monthly Magazine               British
#
#                                               Keywords      Origin
# 0                                                  NaN  HathiTrust
# 1    Translation from Sanskrti ("The Churning of th...  HathiTrust
# 2                    Introduction by Francis H. Skrine   Gutenberg
# 3                                                  NaN   Gutenberg
# 4                                                  NaN  HathiTrust
# ..                                                 ...         ...
# 105                                                NaN         NaN
# 106                                                NaN         NaN
# 107                            Translated by G. Oswell         NaN
# 108                                                NaN         NaN
# 109                                                NaN   Gutenberg
#
# [110 rows x 11 columns]

# %%
csal_meta_df.head(10)
# Out:
#                                                 Text  \
# 0  W-D-Arnold-Oakfield-or-Fellowship-in-the-East-...
# 1  F-W-Bain-Digit-of-the-Moon-A-Hindoo-Love-Story...
# 2           S-B-Banerjea-Tales-of-Bengal-Fiction.txt
# 3       Edmund-Candler-The-Sepoy-1919-Nonfiction.txt
# 4         Edmund-Candler-Abdication-1922-fiction.txt
# 5  Edmund-Candler-Siri-Ram-Revolutionist-A-Transc...
# 6  Edmund-Candler-The-Mantle-of-the-East-1910-Non...
# 7  Edmund-Candler-The-Year-of-Chivalry-1916-nonfi...
# 8  Bankim-Chandra-Chatterji-Anandamath-Dawn-Over-...
# 9  Bankim-Chandra-Chatterji-Kapalkundala-Translat...
#
#                      Author                                 Title  Year  \
# 0  William Delafield Arnold  Oakfield; Or, Fellowship in the East  1855
# 1      Francis William Bain                   A Hindoo Love Story  1898
# 2             S.B. Banerjea                       Tales of Bengal  1910
# 3            Edmund Candler                             The Sepoy  1919
# 4            Edmund Candler                            Abdication  1922
# 5            Edmund Candler               Siri Ram, Revolutionist  1911
# 6            Edmund Candler                    Mantle of the East  1910
# 7            Edmund Candler                      Year of Chivalry  1916
# 8  Bankim Chandra Chatterji           Anandamath: Dawn Over india  1941
# 9  Bankim Chandra Chatterji                          Kapalkundala  1919
#
#    Original (if translated)       Genre          Publisher Location  \
# 0                       NaN     Fiction                   Cambridge
# 1                       NaN     Fiction                      London
# 2                       NaN     Fiction  New York, Bombay, Calcutta
# 3                       NaN     Fiction                      London
# 4                       NaN     Fiction              London, Bombay
# 5                       NaN     Fiction              London, Bombay
# 6                       NaN  Nonfiction                      London
# 7                       NaN  Nonfiction                      London
# 8                    1882.0     Fiction                    New York
# 9                    1866.0     Fiction                    Calcutta
#
#                                     Publisher Name Nationality of Author  \
# 0  Metcalf and Company, Printers to the University               British
# 1                               Methuen & Co. Ltd.               British
# 2                         Longmans, Green, and Co.           South Asian
# 3                                      John Murray               British
# 4                                  Constable & Co.               British
# 5                                  Constable & Co.               British
# 6                       William Blackwood and Sons               British
# 7          Simpkin, Marshall, Hamilton, Kent & Co.               British
# 8                              Devin-Adair Company           South Asian
# 9                                      K.M. Bagchi           South Asian
#
#                                             Keywords      Origin
# 0                                                NaN  HathiTrust
# 1  Translation from Sanskrti ("The Churning of th...  HathiTrust
# 2                  Introduction by Francis H. Skrine   Gutenberg
# 3                                                NaN   Gutenberg
# 4                                                NaN  HathiTrust
# 5                                                NaN  HathiTrust
# 6                                                NaN  HathiTrust
# 7                                                NaN  HathiTrust
# 8  Translation; Translated by Basanta Koomar Roy....  HathiTrust
# 9     Translation; translated by Devendra nath Ghose  Wikisource

# %%
csal_meta_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Text                      110 non-null    object
#  1   Author                    110 non-null    object
#  2   Title                     110 non-null    object
#  3   Year                      110 non-null    int64
#  4   Original (if translated)  14 non-null     float64
#  5   Genre                     110 non-null    object
#  6   Publisher Location        84 non-null     object
#  7   Publisher Name            81 non-null     object
#  8   Nationality of Author     110 non-null    object
#  9   Keywords                  50 non-null     object
#  10  Origin                    101 non-null    object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 9.6+ KB

# %%
csal_meta_df.describe(include="all")
# Out:
#                                                      Text           Author  \
# count                                                 110              110
# unique                                                110               44
# top     W-D-Arnold-Oakfield-or-Fellowship-in-the-East-...  Rudyard Kipling
# freq                                                    1               11
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#                                        Title         Year  \
# count                                    110   110.000000
# unique                                   110          NaN
# top     Oakfield; Or, Fellowship in the East          NaN
# freq                                       1          NaN
# mean                                     NaN  1903.627273
# std                                      NaN    19.213365
# min                                      NaN  1828.000000
# 25%                                      NaN  1894.000000
# 50%                                      NaN  1908.000000
# 75%                                      NaN  1917.000000
# max                                      NaN  1941.000000
#
#         Original (if translated)    Genre Publisher Location  \
# count                  14.000000      110                 84
# unique                       NaN        4                 22
# top                          NaN  Fiction             London
# freq                         NaN       84                 30
# mean                 1891.928571      NaN                NaN
# std                    21.211261      NaN                NaN
# min                  1857.000000      NaN                NaN
# 25%                  1874.250000      NaN                NaN
# 50%                  1897.500000      NaN                NaN
# 75%                  1910.750000      NaN                NaN
# max                  1916.000000      NaN                NaN
#
#            Publisher Name Nationality of Author          Keywords     Origin
# count                  81                   110                50        101
# unique                 59                     7                41          5
# top     Macmillan and Co.               British  Juvenile Fiction  Gutenberg
# freq                    5                    51                 5         64
# mean                  NaN                   NaN               NaN        NaN
# std                   NaN                   NaN               NaN        NaN
# min                   NaN                   NaN               NaN        NaN
# 25%                   NaN                   NaN               NaN        NaN
# 50%                   NaN                   NaN               NaN        NaN
# 75%                   NaN                   NaN               NaN        NaN
# max                   NaN                   NaN               NaN        NaN

# %% [markdown]
# Our task today is to investigate whether the South Asian or "foreign" writers use a higher TTR in their works. So the most important column for us at this point is `Nationality of Author`. Let's have a closer look at what it contains.

# %%
csal_meta_df['Nationality of Author'].value_counts()
# Out:
# Nationality of Author
# British                 51
# South Asian             35
# American                13
# Canadian                 5
# Irish                    3
# South Asian; British     2
# British, American        1
# Name: count, dtype: int64

# %%
csal_meta_df['Nationality of Author'].value_counts().plot(kind="pie", figsize=(7, 7))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Let's also have a look at `Genre`, which might be interesting to us in a bit as well...

# %%
csal_meta_df['Genre'].value_counts()
# Out:
# Genre
# Fiction       84
# Nonfiction    14
# Poetry        10
# Drama          2
# Name: count, dtype: int64

# %%
csal_meta_df['Genre'].value_counts().plot(kind="pie", figsize=(7, 7))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Approaching TTR Task in Pandas
#
# Okay, now let's take a step back and re-approach our TTR task with a Pandas mindset.
#
# When we took on this task in the first half of the semester, we just wanted to output our analysis to a CSV spreadsheet file and consider our task done.
#
# Now that we have been introduced to Pandas, let's instead plan on gathering our results into DataFrames, with the aim of eventually putting new columns into the `csal_meta_df` DataFrame with TTR values for every text: overall types, overall tokens, overall TTR; standardized types, standardized tokens, standardized TTR. Once we have that big DataFrame with those extra columns, we'll be able to do some fancy analysis!
#
# We'll start by recycling our code from a few weeks ago to generate the same CSV files... except this time, we'll load those CSVs back into Python as Pandas dataframes!

# %% [markdown]
# ## Generating TTR CSV files... and Loading Them Back as Pandas DataFrames
#
# Let's start by using some code directly recycled** from the Week 5 lecture.
#
# The code below iterates through all the files in the `csal` folder, which contains all the CSAL texts, and generates CSV files for their standard and overall values. There are 110 files in the CSAL dataset, some of them quite large, so this will take a second!
#
# ** There are two tiny differences between this code and the code we used in Week 5: I have grabbed the full file name with extension of each text file in the `Text` column, so that it matches what's in the `csal_meta_df` `Text` columns. You'll see why that's important in a second... The other difference is that this code now labels the columns "Overall Types" or "Standardized Types" (etc) for more precise columns labels that will also come in handy later.
#
# ### BEFORE RUNNING THE BELOW CELL: It takes a while to run this code, since the CSAL dataset is pretty big, so I have placed the output files of the below cell in your JupyterHubs for demonstration purposes! IF YOU'RE FOLLOWING ALONG IN CLASS, LET'S AVOID CRASHING THE SERVER BY SKIPPING THE BELOW STEP.

# %%
import re
from pathlib import Path

folder_path = "csal/" # We're telling the code to look in the "csal/" subfolder, where the CSAL files all live.

sample_size = 0

file = open("ttr-overall.csv", mode="w", encoding="utf-8")

file.write('"Text","Overall Types","Overall Tokens","Overall TTR"\n') # Column labels are more precise, identifying whether the column records "Overall" or "Standardized" values

print(sorted(Path(folder_path).glob('*.txt')))
for file_path in sorted(Path(folder_path).glob('*.txt')):
    
    text = open(file_path, encoding='utf-8').read()
    text = re.sub("[^a-zA-Z0-9]", " ", text)
    
    text_words = text.split()
    tokens = len(text_words)
    
    if sample_size == 0 or tokens < sample_size:
        sample_size = tokens
    
    unique_words = []
    
    for word in text_words:
        word = word.lower()
        if word not in unique_words:
            unique_words.append(word)
            
    types = len(unique_words)
    
    ttr = (types / tokens) * 100    
    file.write(f'"{file_path.name}",{types},{tokens},{ttr}\n') # path.name used rather than path.stem so that recoreded filenames match CSAL metadata

file.close()



file = open("ttr-standardized.csv", mode="w", encoding="utf-8")

file.write('"Text","Standardized Types","Standardized Tokens","Standardized TTR"\n') # Column labels are more precise, identifying whether the column records "Overall" or "Standardized" values

for file_path in sorted(Path(folder_path).glob('*.txt')):
    text = open(file_path, encoding='utf-8').read()
    text = re.sub("[^a-zA-Z0-9]", " ", text)
    
    text_words = text.split()
    text_words_standardized = text_words[:sample_size]
    tokens_standardized = len(text_words_standardized)

    unique_words_standardized = []
    
    for word in text_words_standardized:
        word = word.lower()
        if word not in unique_words_standardized:
            unique_words_standardized.append(word)
            
    types_standardized = len(unique_words_standardized)
    
    ttr_standardized = (types_standardized / tokens_standardized) * 100
    
    file.write(f'"{file_path.name}",{types_standardized},{tokens_standardized},{ttr_standardized}\n') # path.name used rather than path.stem so that recoreded filenames match CSAL metadata

file.close()
# Out:
# [PosixPath('csal/1897-Alice-Macdonald-Fleming-A-Pinchbeck-Goddess-1897-fiction.txt'), PosixPath('csal/Alice-Elizabeth-Dracott-Simla-Village-Tales-or-Folk-Tales-from-the-Himalayas-1906-fiction.txt'), PosixPath('csal/Annie-Besant-The-Case-for-India-1917-Nonfiction.txt'), PosixPath('csal/Arthur-Conan-Doyle-The-Sign-of-the-Four-1890.txt'), PosixPath('csal/B-M-Croker-Dianna-Barrington-A-Romance-of-Central-India-1888-fiction.txt'), PosixPath('csal/B-M-Croker-Proper-Pride-1882-fiction.txt'), PosixPath('csal/B-M-Croker-Rolling-Stone-1911.txt'), PosixPath('csal/Bankim-Chandra-Chatterji-Anandamath-Dawn-Over-India-Translation-1940.txt'), PosixPath('csal/Bankim-Chandra-Chatterji-Kapalkundala-Translation-1919-fiction.txt'), PosixPath('csal/Bankim-Chandra-Chatterji-Krishnakantas-Will-1917-fiction-translation.txt'), PosixPath('csal/Bankim-Chandra-Chatterji-Rajmohans-Wife-a-Novel-1864-fiction.txt'), PosixPath('csal/Bankim-Chandra-Chatterji-The-Poison-Tree-A-Tale-of-Hindu-Life-in-Bengal.txt'), PosixPath('csal/Collected-Poems-of-Henry-Derozio-Downloadable.txt'), PosixPath('csal/Cornelia-Sorabji-Between-the-Twilights-1908-nonfiction.txt'), PosixPath('csal/Cornelia-Sorabji-Indian-Tales-of-the-Great-Ones-Among-Men-and-Bird-People-Fiction.txt'), PosixPath('csal/Cornelia-Sorabji-Love-and-Life-Beyond-the-Purdah-1901-fiction.txt'), PosixPath('csal/Cornelia-Sorabji-Shubala-A-Child-Mother-1920-nonfiction.txt'), PosixPath('csal/Cornelia-Sorabji-Sun-Babies-Studies-in-the-Child-Life-of-India-1904-Fiction.txt'), PosixPath('csal/Dhan-Gopal-Mukerji-Beast-and-Man-in-India-1923.txt'), PosixPath('csal/Dhan-Gopal-Mukerji-Kari-the-Elephant-1922-Fiction.txt'), PosixPath('csal/Dhan-Gopal-Mukerji-Layla-Majnu-A-Musical-Play-in-Three-Acts-1916-Drama.txt'), PosixPath('csal/Dhan-Gopal-Mukerji-Rajani-Songs-of-the-Night-1916-Poetry.txt'), PosixPath('csal/Dhan-Gopal-Mukerji-Songs-of-Twilight-1917-Poetry.txt'), PosixPath('csal/E-M-Forster-A-Passage-to-India-1923-fiction.txt'), PosixPath('csal/Edmund-Candler-Abdication-1922-fiction.txt'), PosixPath('csal/Edmund-Candler-Siri-Ram-Revolutionist-A-Transcript-from-Life-Fiction.txt'), PosixPath('csal/Edmund-Candler-The-Mantle-of-the-East-1910-Nonfiction.txt'), PosixPath('csal/Edmund-Candler-The-Sepoy-1919-Nonfiction.txt'), PosixPath('csal/Edmund-Candler-The-Year-of-Chivalry-1916-nonfiction.txt'), PosixPath('csal/Edward-S-Ellis-The-Jungle-Fugitives-A-Tale-of-Life-and-Adventure-in-India-1903-Fiction.txt'), PosixPath('csal/F-W-Bain-Digit-of-the-Moon-A-Hindoo-Love-Story-Translation-Fiction-1901.txt'), PosixPath('csal/Flora-Annie-Steel-A-Prince-of-Dreamers-1909-fiction.txt'), PosixPath('csal/Flora-Annie-Steel-Adventures-of-Akbar-1913.txt'), PosixPath('csal/Flora-Annie-Steel-From-the-Five-Rivers.txt'), PosixPath('csal/Flora-Annie-Steel-On-the-face-of-the-waters.txt'), PosixPath('csal/Flora-Annie-Steel-Tales-of-the-Punjab-Folklore-of-India.txt'), PosixPath('csal/Flora-Annie-Steel-The-Flower-of-Forgiveness-1894-fiction.txt'), PosixPath('csal/Flora-Annie-Steel-The-Potters-Thumb-1900.txt'), PosixPath('csal/Flora-Annie-Steel-Voices-in-the-Night-1900.txt'), PosixPath('csal/Frederick-P-Gibbon-The-Disputed-V-C-A-Tale-of-the-Indian-Mutiny.txt'), PosixPath('csal/G-A-Henty-At-The-Point-of-the-Bayonet-A-Tale-of-the-Mahratta-War.txt'), PosixPath('csal/G-A-Henty-In-Times-of-Peril-A-Tale-of-India-Fiction.txt'), PosixPath('csal/G-A-Henty-Rujub-the-Juggler-Fiction.txt'), PosixPath('csal/G-A-Henty-The-Tiger-of-Mysore-A-Story-of-the-War-With-Tippoo-Sahib.txt'), PosixPath('csal/G-A-Henty-Through-the-Sikh-War-A-Tale-of-the-conquest-ofthe-Punjab-Fiction.txt'), PosixPath('csal/George-Manville-Fenn-Begumbach-A-Tale-of-the-Indian-Mutiny-Fiction.txt'), PosixPath('csal/Georgene-Faulkner-The-White-Elephant-and-Other-Tales-from-Old-India-1929-fiction.txt'), PosixPath('csal/Helen-S-Dyer-Pandita-Ramabai-The-Story-of-her-Life-1900-nonfiction.txt'), PosixPath('csal/Henry-Louis-Vivian-Derozio-Poems-1923-poetry.txt'), PosixPath('csal/Inayat-Khan-and-Jessie-Duncan-Westbroo ...

# %% [markdown]
# Okay, that has left us with our familiar `ttr-overall.csv` and `ttr-standardized.csv` results files.
#
# Let's use our old friend `pd.read_csv()` to load each of those newly created CSV files as Pandas DataFrames!
#
# Note: I ran the notebook at home and created pre-computed files that I've named the pre-computed files `ttr-overall_prebaked.csv` and `ttr-standardized_prebaked.cvs` so that if the above code got modified and didn't work or if the kernel got interrupted or something, I would still have the precomputed files w/ the full, uncorrupted data.
#
# I'll use those now, for purposes of live, in-class demonstrations.  At your leisure, you can run the above code yourself and use the files you computed, after modifying which files are read in below.

# %%
#overall_ttr_df = pd.read_csv("ttr-overall_prebaked.csv")
overall_ttr_df = pd.read_csv("ttr-overall.csv")

# %%
overall_ttr_df
# Out:
#                                                   Text  Overall Types  \
# 0    1897-Alice-Macdonald-Fleming-A-Pinchbeck-Godde...           7369
# 1    Alice-Elizabeth-Dracott-Simla-Village-Tales-or...           3492
# 2    Annie-Besant-The-Case-for-India-1917-Nonfictio...           3668
# 3     Arthur-Conan-Doyle-The-Sign-of-the-Four-1890.txt           5379
# 4    B-M-Croker-Dianna-Barrington-A-Romance-of-Cent...          11265
# ..                                                 ...            ...
# 105  Talbot-Mundy-The-Red-Flame-of-Erinpura-fiction...           6563
# 106  Talbot-Mundy-The-Winds-of-the-World-1915-ficti...           5361
# 107  Toru-Dutt-Ancient-Ballads-And-Legends-of-Hindu...           4326
# 108  W-D-Arnold-Oakfield-or-Fellowship-in-the-East-...          11181
# 109  W-S-R-Hodson-Twelve-Years-of-a-soldiers-life-i...           9346
#
#      Overall Tokens  Overall TTR
# 0             69286    10.635626
# 1             41675     8.379124
# 2             18153    20.206027
# 3             43804    12.279700
# 4            138618     8.126650
# ..              ...          ...
# 105           48937    13.411120
# 106           52391    10.232674
# 107           22740    19.023747
# 108          148965     7.505790
# 109          133894     6.980148
#
# [110 rows x 4 columns]

# %%
#standardized_ttr_df = pd.read_csv("ttr-standardized_prebaked.csv")
standardized_ttr_df = pd.read_csv("ttr-standardized.csv")

# %%
standardized_ttr_df
# Out:
#                                                   Text  Standardized Types  \
# 0    1897-Alice-Macdonald-Fleming-A-Pinchbeck-Godde...                1419
# 1    Alice-Elizabeth-Dracott-Simla-Village-Tales-or...                1041
# 2    Annie-Besant-The-Case-for-India-1917-Nonfictio...                1323
# 3     Arthur-Conan-Doyle-The-Sign-of-the-Four-1890.txt                1302
# 4    B-M-Croker-Dianna-Barrington-A-Romance-of-Cent...                1489
# ..                                                 ...                 ...
# 105  Talbot-Mundy-The-Red-Flame-of-Erinpura-fiction...                1485
# 106  Talbot-Mundy-The-Winds-of-the-World-1915-ficti...                1250
# 107  Toru-Dutt-Ancient-Ballads-And-Legends-of-Hindu...                1504
# 108  W-D-Arnold-Oakfield-or-Fellowship-in-the-East-...                1170
# 109  W-S-R-Hodson-Twelve-Years-of-a-soldiers-life-i...                1364
#
#      Standardized Tokens  Standardized TTR
# 0                   4051         35.028388
# 1                   4051         25.697359
# 2                   4051         32.658603
# 3                   4051         32.140212
# 4                   4051         36.756356
# ..                   ...               ...
# 105                 4051         36.657615
# 106                 4051         30.856579
# 107                 4051         37.126635
# 108                 4051         28.881758
# 109                 4051         33.670699
#
# [110 rows x 4 columns]

# %% [markdown]
# # Merging DataFrames
#
# Okay, let's say that instead of having our overall and standardized TTR values in separate DataFrames, we wanted to **merge** them into a single DataFrame that contains all the relevant data.
#
# Well, we can do that quite easily with Pandas's `.merge()` method. We can only merge DataFrames that contain one column in common — otherwise, Pandas won't know exactly how to combine them. But thankfully our DataFrames do have one column in common: `Text`.

# %%
overall_ttr_df
# Out:
#                                                   Text  Overall Types  \
# 0    1897-Alice-Macdonald-Fleming-A-Pinchbeck-Godde...           7369
# 1    Alice-Elizabeth-Dracott-Simla-Village-Tales-or...           3492
# 2    Annie-Besant-The-Case-for-India-1917-Nonfictio...           3668
# 3     Arthur-Conan-Doyle-The-Sign-of-the-Four-1890.txt           5379
# 4    B-M-Croker-Dianna-Barrington-A-Romance-of-Cent...          11265
# ..                                                 ...            ...
# 105  Talbot-Mundy-The-Red-Flame-of-Erinpura-fiction...           6563
# 106  Talbot-Mundy-The-Winds-of-the-World-1915-ficti...           5361
# 107  Toru-Dutt-Ancient-Ballads-And-Legends-of-Hindu...           4326
# 108  W-D-Arnold-Oakfield-or-Fellowship-in-the-East-...          11181
# 109  W-S-R-Hodson-Twelve-Years-of-a-soldiers-life-i...           9346
#
#      Overall Tokens  Overall TTR
# 0             69286    10.635626
# 1             41675     8.379124
# 2             18153    20.206027
# 3             43804    12.279700
# 4            138618     8.126650
# ..              ...          ...
# 105           48937    13.411120
# 106           52391    10.232674
# 107           22740    19.023747
# 108          148965     7.505790
# 109          133894     6.980148
#
# [110 rows x 4 columns]

# %%
standardized_ttr_df
# Out:
#                                                   Text  Standardized Types  \
# 0    1897-Alice-Macdonald-Fleming-A-Pinchbeck-Godde...                1419
# 1    Alice-Elizabeth-Dracott-Simla-Village-Tales-or...                1041
# 2    Annie-Besant-The-Case-for-India-1917-Nonfictio...                1323
# 3     Arthur-Conan-Doyle-The-Sign-of-the-Four-1890.txt                1302
# 4    B-M-Croker-Dianna-Barrington-A-Romance-of-Cent...                1489
# ..                                                 ...                 ...
# 105  Talbot-Mundy-The-Red-Flame-of-Erinpura-fiction...                1485
# 106  Talbot-Mundy-The-Winds-of-the-World-1915-ficti...                1250
# 107  Toru-Dutt-Ancient-Ballads-And-Legends-of-Hindu...                1504
# 108  W-D-Arnold-Oakfield-or-Fellowship-in-the-East-...                1170
# 109  W-S-R-Hodson-Twelve-Years-of-a-soldiers-life-i...                1364
#
#      Standardized Tokens  Standardized TTR
# 0                   4051         35.028388
# 1                   4051         25.697359
# 2                   4051         32.658603
# 3                   4051         32.140212
# 4                   4051         36.756356
# ..                   ...               ...
# 105                 4051         36.657615
# 106                 4051         30.856579
# 107                 4051         37.126635
# 108                 4051         28.881758
# 109                 4051         33.670699
#
# [110 rows x 4 columns]

# %% [markdown]
# Below is the command we use to `.merge()` our two DataFrames, **"on"** the column they have in common.

# %%
pd.merge(overall_ttr_df, standardized_ttr_df, on="Text")
# Out:
#                                                   Text  Overall Types  \
# 0    1897-Alice-Macdonald-Fleming-A-Pinchbeck-Godde...           7369
# 1    Alice-Elizabeth-Dracott-Simla-Village-Tales-or...           3492
# 2    Annie-Besant-The-Case-for-India-1917-Nonfictio...           3668
# 3     Arthur-Conan-Doyle-The-Sign-of-the-Four-1890.txt           5379
# 4    B-M-Croker-Dianna-Barrington-A-Romance-of-Cent...          11265
# ..                                                 ...            ...
# 105  Talbot-Mundy-The-Red-Flame-of-Erinpura-fiction...           6563
# 106  Talbot-Mundy-The-Winds-of-the-World-1915-ficti...           5361
# 107  Toru-Dutt-Ancient-Ballads-And-Legends-of-Hindu...           4326
# 108  W-D-Arnold-Oakfield-or-Fellowship-in-the-East-...          11181
# 109  W-S-R-Hodson-Twelve-Years-of-a-soldiers-life-i...           9346
#
#      Overall Tokens  Overall TTR  Standardized Types  Standardized Tokens  \
# 0             69286    10.635626                1419                 4051
# 1             41675     8.379124                1041                 4051
# 2             18153    20.206027                1323                 4051
# 3             43804    12.279700                1302                 4051
# 4            138618     8.126650                1489                 4051
# ..              ...          ...                 ...                  ...
# 105           48937    13.411120                1485                 4051
# 106           52391    10.232674                1250                 4051
# 107           22740    19.023747                1504                 4051
# 108          148965     7.505790                1170                 4051
# 109          133894     6.980148                1364                 4051
#
#      Standardized TTR
# 0           35.028388
# 1           25.697359
# 2           32.658603
# 3           32.140212
# 4           36.756356
# ..                ...
# 105         36.657615
# 106         30.856579
# 107         37.126635
# 108         28.881758
# 109         33.670699
#
# [110 rows x 7 columns]

# %% [markdown]
# Now let's go ahead and stick that into a variable

# %%
ttr_df = pd.merge(overall_ttr_df, standardized_ttr_df, on="Text")

# %%
ttr_df
# Out:
#                                                   Text  Overall Types  \
# 0    1897-Alice-Macdonald-Fleming-A-Pinchbeck-Godde...           7369
# 1    Alice-Elizabeth-Dracott-Simla-Village-Tales-or...           3492
# 2    Annie-Besant-The-Case-for-India-1917-Nonfictio...           3668
# 3     Arthur-Conan-Doyle-The-Sign-of-the-Four-1890.txt           5379
# 4    B-M-Croker-Dianna-Barrington-A-Romance-of-Cent...          11265
# ..                                                 ...            ...
# 105  Talbot-Mundy-The-Red-Flame-of-Erinpura-fiction...           6563
# 106  Talbot-Mundy-The-Winds-of-the-World-1915-ficti...           5361
# 107  Toru-Dutt-Ancient-Ballads-And-Legends-of-Hindu...           4326
# 108  W-D-Arnold-Oakfield-or-Fellowship-in-the-East-...          11181
# 109  W-S-R-Hodson-Twelve-Years-of-a-soldiers-life-i...           9346
#
#      Overall Tokens  Overall TTR  Standardized Types  Standardized Tokens  \
# 0             69286    10.635626                1419                 4051
# 1             41675     8.379124                1041                 4051
# 2             18153    20.206027                1323                 4051
# 3             43804    12.279700                1302                 4051
# 4            138618     8.126650                1489                 4051
# ..              ...          ...                 ...                  ...
# 105           48937    13.411120                1485                 4051
# 106           52391    10.232674                1250                 4051
# 107           22740    19.023747                1504                 4051
# 108          148965     7.505790                1170                 4051
# 109          133894     6.980148                1364                 4051
#
#      Standardized TTR
# 0           35.028388
# 1           25.697359
# 2           32.658603
# 3           32.140212
# 4           36.756356
# ..                ...
# 105         36.657615
# 106         30.856579
# 107         37.126635
# 108         28.881758
# 109         33.670699
#
# [110 rows x 7 columns]

# %% [markdown]
# # Merging the TTR Data with the CSAL Metadata
#
# It's worth remembering at this time that the CSAL Metadata (currently stored in `csal_meta_df`) also contains that same `Text` column — and so we can also create a mega-merged DataFrame that contains all the CSAL metadata and all the TTR analysis we've just done. This will allow us to analyze our TTRs by our various metadata categories, including author nationality.

# %%
csal_ttr_df = pd.merge(csal_meta_df, ttr_df, on="Text")

# %%
csal_ttr_df
# Out:
#                                                   Text  \
# 0    W-D-Arnold-Oakfield-or-Fellowship-in-the-East-...
# 1    F-W-Bain-Digit-of-the-Moon-A-Hindoo-Love-Story...
# 2             S-B-Banerjea-Tales-of-Bengal-Fiction.txt
# 3         Edmund-Candler-The-Sepoy-1919-Nonfiction.txt
# 4           Edmund-Candler-Abdication-1922-fiction.txt
# ..                                                 ...
# 105  Collected-Poems-of-Henry-Derozio-Downloadable.txt
# 106  Peary-Chand-Mitter-A-Biographical-Sketch-of-Da...
# 107  Peary-Chand-Mitter-The-Spoilt-Child-A-Tale-of-...
# 108  Flora-Annie-Steel-The-Flower-of-Forgiveness-18...
# 109   Arthur-Conan-Doyle-The-Sign-of-the-Four-1890.txt
#
#                          Author  \
# 0      William Delafield Arnold
# 1          Francis William Bain
# 2                 S.B. Banerjea
# 3                Edmund Candler
# 4                Edmund Candler
# ..                          ...
# 105  Henry Louis Vivian Derozio
# 106           Peary Chand Mitra
# 107           Peary Chand Mitra
# 108           Flora Annie Steel
# 109          Arthur Conan Doyle
#
#                                                  Title  Year  \
# 0                 Oakfield; Or, Fellowship in the East  1855
# 1                                  A Hindoo Love Story  1898
# 2                                      Tales of Bengal  1910
# 3                                            The Sepoy  1919
# 4                                           Abdication  1922
# ..                                                 ...   ...
# 105                                    Collected Poems  1828
# 106                A Biographical Sketch of David Hare  1877
# 107  The Spoilt Child (translation of Alaler Gharer...  1893
# 108                          The Flower of Forgiveness  1894
# 109                               The Sign of the Four  1890
#
#      Original (if translated)       Genre          Publisher Location  \
# 0                         NaN     Fiction                   Cambridge
# 1                         NaN     Fiction                      London
# 2                         NaN     Fiction  New York, Bombay, Calcutta
# 3                         NaN     Fiction                      London
# 4                         NaN     Fiction              London, Bombay
# ..                        ...         ...                         ...
# 105                       NaN      Poetry                    Calcutta
# 106                       NaN  Nonfiction                    Calcutta
# 107                    1857.0     Fiction                    Calcutta
# 108                       NaN     Fiction            London, New York
# 109                       NaN     Fiction        London, Philadelphia
#
#                                       Publisher Name Nationality of Author  \
# 0    Metcalf and Company, Printers to the University               British
# 1                                 Methuen & Co. Ltd.               British
# 2                           Longmans, Green, and Co.           South Asian
# 3                                        John Murray               British
# 4                                    Constable & Co.               British
# ..                                               ...                   ...
# 105                             Samuel Smith and Co.           South Asian
# 106                                W. Newman and Co.           South Asian
# 107                           Thacker, Spink and Co.           South Asian
# 108                                Macmillan and Co.               British
# 109                    Lippincott's Monthly Magazine               British
#
#                                               Keywords      Origin  \
# 0                                                  NaN  HathiTrust
# 1    Translation from Sanskrti ("The Churning of th...  HathiTrust
# 2                    Introduction by Francis H. Skrine   Gutenberg
# 3                                                  NaN   Gutenberg
# 4                                                  NaN  HathiTrust
# ..                                                 ...         ...
# 105                                                NaN         NaN
# 106                                                NaN         NaN
# 107                            Translated by G. Oswell         NaN
# 108                                                NaN         NaN
# 109                                                NaN   Gutenberg
#
#      Overall Types  Overall Tokens  Overall TTR  Standardized Types  \
# 0            11181          148965     7.505790                1170
# 1             3883           29953    12.963643                1277
# 2             6797           46332    14.670206                1667
# 3             6672           48275    13.820818                1350
# 4            10047           82903    12.118982                1422
# ..             ...             ...          ...                 ...
# 105           5391           46855    11.505709                1181
# 106           6845           52642    13.002925                1268
# 107           7787           70205    11.091803                1303
# 108           8865           83093    10.668769                1370
# 109           5379           43804    12.279700                1302
#
#      Standardized Tokens  Standardized TTR
# 0                   4051         28.881758
# 1                   4051         31.523081
# 2                   4051         41.150333
# 3                   4051         33.325105
# 4                   4051         35.102444
# ..                   ...               ...
# 105                 4051         29.153295
# 106                 4051         31.300913
# 107                 4051         32.164898
# 108                 4051         33.818810
# 109                 4051         32.140212
#
# [110 rows x 17 columns]

# %% [markdown]
# Let's learn a little more about this new mega-DataFrame we're created...

# %%
csal_ttr_df.describe(include="all")
# Out:
#                                                      Text           Author  \
# count                                                 110              110
# unique                                                110               44
# top     W-D-Arnold-Oakfield-or-Fellowship-in-the-East-...  Rudyard Kipling
# freq                                                    1               11
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#                                        Title         Year  \
# count                                    110   110.000000
# unique                                   110          NaN
# top     Oakfield; Or, Fellowship in the East          NaN
# freq                                       1          NaN
# mean                                     NaN  1903.627273
# std                                      NaN    19.213365
# min                                      NaN  1828.000000
# 25%                                      NaN  1894.000000
# 50%                                      NaN  1908.000000
# 75%                                      NaN  1917.000000
# max                                      NaN  1941.000000
#
#         Original (if translated)    Genre Publisher Location  \
# count                  14.000000      110                 84
# unique                       NaN        4                 22
# top                          NaN  Fiction             London
# freq                         NaN       84                 30
# mean                 1891.928571      NaN                NaN
# std                    21.211261      NaN                NaN
# min                  1857.000000      NaN                NaN
# 25%                  1874.250000      NaN                NaN
# 50%                  1897.500000      NaN                NaN
# 75%                  1910.750000      NaN                NaN
# max                  1916.000000      NaN                NaN
#
#            Publisher Name Nationality of Author          Keywords     Origin  \
# count                  81                   110                50        101
# unique                 59                     7                41          5
# top     Macmillan and Co.               British  Juvenile Fiction  Gutenberg
# freq                    5                    51                 5         64
# mean                  NaN                   NaN               NaN        NaN
# std                   NaN                   NaN               NaN        NaN
# min                   NaN                   NaN               NaN        NaN
# 25%                   NaN                   NaN               NaN        NaN
# 50%                   NaN                   NaN               NaN        NaN
# 75%                   NaN                   NaN               NaN        NaN
# max                   NaN                   NaN               NaN        NaN
#
#         Overall Types  Overall Tokens  Overall TTR  Standardized Types  \
# count      110.000000      110.000000   110.000000          110.000000
# unique            NaN             NaN          NaN                 NaN
# top               NaN             NaN          NaN                 NaN
# freq              NaN             NaN          NaN                 NaN
# mean      6312.981818    65174.854545    12.248220         1259.809091
# std       2827.401670    42907.137253     5.053967          171.322567
# min       1115.000000     4051.000000     4.813737          709.000000
# 25%       4528.250000    31034.250000     8.761210         1174.500000
# 50%       6232.000000    52516.500000    10.825813         1263.000000
# 75%       8648.750000    92339.500000    14.699739         1369.750000
# max      11977.000000   179506.000000    30.191693         1667.000000
#
#         Standardized Tokens  Standardized TTR
# count                 110.0        110.000000
# unique                  NaN               NaN
# top                     NaN               NaN
# freq                    NaN               NaN
# mean                 4051.0         31.098719
# std                     0.0          4.229143
# min                  4051.0         17.501851
# 25%                  4051.0         28.992841
# 50%                  4051.0         31.177487
# 75%                  4051.0         33.812639
# max                  4051.0         41.150333

# %% [markdown]
# This is one of those occasions when `include="all"` parameter on the `df.describe()` method gives us more info that we really want. Let's try again without, which will only give us the "greatest hits" columns...

# %%
csal_ttr_df.describe()
# Out:
#               Year  Original (if translated)  Overall Types  Overall Tokens  \
# count   110.000000                 14.000000     110.000000      110.000000
# mean   1903.627273               1891.928571    6312.981818    65174.854545
# std      19.213365                 21.211261    2827.401670    42907.137253
# min    1828.000000               1857.000000    1115.000000     4051.000000
# 25%    1894.000000               1874.250000    4528.250000    31034.250000
# 50%    1908.000000               1897.500000    6232.000000    52516.500000
# 75%    1917.000000               1910.750000    8648.750000    92339.500000
# max    1941.000000               1916.000000   11977.000000   179506.000000
#
#        Overall TTR  Standardized Types  Standardized Tokens  Standardized TTR
# count   110.000000          110.000000                110.0        110.000000
# mean     12.248220         1259.809091               4051.0         31.098719
# std       5.053967          171.322567                  0.0          4.229143
# min       4.813737          709.000000               4051.0         17.501851
# 25%       8.761210         1174.500000               4051.0         28.992841
# 50%      10.825813         1263.000000               4051.0         31.177487
# 75%      14.699739         1369.750000               4051.0         33.812639
# max      30.191693         1667.000000               4051.0         41.150333

# %% [markdown]
# # Sorting by Column
#
# Before we jump into our actual task for this week, let's see how you would sort the full dataset by Standardized TTR, from lowest to highest; then from highest to lowest.

# %%
csal_ttr_df.sort_values(by='Standardized TTR', ascending=True)
# Out:
#                                                   Text  \
# 34   Georgene-Faulkner-The-White-Elephant-and-Other...
# 100            Rabindranath-Tagore-The-Post-Office.txt
# 51                 Rudyard-Kipling-Just-So-Stories.txt
# 10   Bankim-Chandra-Chatterji-Krishnakantas-Will-19...
# 64   Dhan-Gopal-Mukerji-Kari-the-Elephant-1922-Fict...
# ..                                                 ...
# 30   Toru-Dutt-Ancient-Ballads-And-Legends-of-Hindu...
# 17          Maud-Diver-Captain-Desmond-V-C-Fiction.txt
# 32          S-M-Edwardes-By-Ways-of-Bombay-Fiction.txt
# 14            B-M-Croker-Proper-Pride-1882-fiction.txt
# 2             S-B-Banerjea-Tales-of-Bengal-Fiction.txt
#
#                         Author  \
# 34           Georgene Faulkner
# 100        Rabindranath Tagore
# 51             Rudyard Kipling
# 10    Bankim Chandra Chatterji
# 64          Dhan Gopal Mukerji
# ..                         ...
# 30                   Toru Dutt
# 17                  Maud Diver
# 32   Stephen Meredyth Edwardes
# 14          Bithia Mary Croker
# 2                S.B. Banerjea
#
#                                                  Title  Year  \
# 34   The White Elephant and Other Tales from Old India  1929
# 100                                    The Post Office  1914
# 51                                     Just So Stories  1902
# 10                                 Krishnakanta's Will  1917
# 64                                   Kari the Elephant  1922
# ..                                                 ...   ...
# 30            Ancient Ballads and Legends of Hindustan  1885
# 17                               Captain Desmond, V.C.  1917
# 32                                   By-Ways of Bombay  1912
# 14                                        Proper Pride  1882
# 2                                      Tales of Bengal  1910
#
#      Original (if translated)       Genre          Publisher Location  \
# 34                        NaN     Fiction                    New York
# 100                    1912.0       Drama                      London
# 51                        NaN     Fiction                         NaN
# 10                     1878.0     Fiction                         NaN
# 64                        NaN     Fiction                    New York
# ..                        ...         ...                         ...
# 30                        NaN      Poetry                      London
# 17                        NaN     Fiction           London, Edinburgh
# 32                        NaN  Nonfiction                         NaN
# 14                        NaN     Fiction                      London
# 2                         NaN     Fiction  New York, Bombay, Calcutta
#
#                  Publisher Name Nationality of Author  \
# 34         P.F. Vollard Company              American
# 100           Macmillan Company           South Asian
# 51                          NaN               British
# 10                          NaN           South Asian
# 64             Dutton & Company           South Asian
# ..                          ...                   ...
# 30     Kegan Paul, Trench & Co.           South Asian
# 17   William Blackwood and Sons               British
# 32                          NaN               British
# 14             Tinsley Brothers                 Irish
# 2      Longmans, Green, and Co.           South Asian
#
#                                            Keywords      Origin  \
# 34                                 Juvenile Fiction   Gutenberg
# 100  Translated from Bengali by Devabrata Mukherjee   Gutenberg
# 51                                 Juvenile fiction   Gutenberg
# 10   Translation; Translated by Dakshina Charan Roy  HathiTrust
# 64                                 Juvenile Fiction   Gutenberg
# ..                                              ...         ...
# 30                       Preface by Edmund W. Gosse   Gutenberg
# 17                                              NaN   Gutenberg
# 32                    Ethnography; Literary Quality   Gutenberg
# 14                                              NaN  HathiTrust
# 2                 Introduction by Francis H. Skrine   Gutenberg
#
#      Overall Types  Overall Tokens  Overall TTR  Standardized Types  \
# 34            1887           17775    10.616034                 709
# 100           1191            7674    15.519937                 785
# 51            2905           30540     9.512115                 895
# 10            3670           37776     9.715163                 901
# 64            2452           19911    12.314801                 908
# ..             ...             ...          ...                 ...
# 30            4326           22740    19.023747                1504
# 17            9344          119562     7.815192                1520
# 32            6234           30912    20.166925                1529
# 14            9971          105895     9.415931                1550
# 2             6797           46332    14.670206                1667
#
#      Standardized Tokens  Standardized TTR
# 34                  4051         17.501851
# 100                 4051         19.377931
# 51                  4051         22.093310
# 10                  4051         22.241422
# 64                  4051         22.414219
# ..                   ...               ...
# 30                  4051         37.126635
# 17                  4051         37.521600
# 32                  4051         37.743767
# 14                  4051         38.262157
# 2                   4051         41.150333
#
# [110 rows x 17 columns]

# %%
csal_ttr_df.sort_values(by='Standardized TTR', ascending=False)
# Out:
#                                                   Text  \
# 2             S-B-Banerjea-Tales-of-Bengal-Fiction.txt
# 14            B-M-Croker-Proper-Pride-1882-fiction.txt
# 32          S-M-Edwardes-By-Ways-of-Bombay-Fiction.txt
# 17          Maud-Diver-Captain-Desmond-V-C-Fiction.txt
# 30   Toru-Dutt-Ancient-Ballads-And-Legends-of-Hindu...
# ..                                                 ...
# 64   Dhan-Gopal-Mukerji-Kari-the-Elephant-1922-Fict...
# 10   Bankim-Chandra-Chatterji-Krishnakantas-Will-19...
# 51                 Rudyard-Kipling-Just-So-Stories.txt
# 100            Rabindranath-Tagore-The-Post-Office.txt
# 34   Georgene-Faulkner-The-White-Elephant-and-Other...
#
#                         Author  \
# 2                S.B. Banerjea
# 14          Bithia Mary Croker
# 32   Stephen Meredyth Edwardes
# 17                  Maud Diver
# 30                   Toru Dutt
# ..                         ...
# 64          Dhan Gopal Mukerji
# 10    Bankim Chandra Chatterji
# 51             Rudyard Kipling
# 100        Rabindranath Tagore
# 34           Georgene Faulkner
#
#                                                  Title  Year  \
# 2                                      Tales of Bengal  1910
# 14                                        Proper Pride  1882
# 32                                   By-Ways of Bombay  1912
# 17                               Captain Desmond, V.C.  1917
# 30            Ancient Ballads and Legends of Hindustan  1885
# ..                                                 ...   ...
# 64                                   Kari the Elephant  1922
# 10                                 Krishnakanta's Will  1917
# 51                                     Just So Stories  1902
# 100                                    The Post Office  1914
# 34   The White Elephant and Other Tales from Old India  1929
#
#      Original (if translated)       Genre          Publisher Location  \
# 2                         NaN     Fiction  New York, Bombay, Calcutta
# 14                        NaN     Fiction                      London
# 32                        NaN  Nonfiction                         NaN
# 17                        NaN     Fiction           London, Edinburgh
# 30                        NaN      Poetry                      London
# ..                        ...         ...                         ...
# 64                        NaN     Fiction                    New York
# 10                     1878.0     Fiction                         NaN
# 51                        NaN     Fiction                         NaN
# 100                    1912.0       Drama                      London
# 34                        NaN     Fiction                    New York
#
#                  Publisher Name Nationality of Author  \
# 2      Longmans, Green, and Co.           South Asian
# 14             Tinsley Brothers                 Irish
# 32                          NaN               British
# 17   William Blackwood and Sons               British
# 30     Kegan Paul, Trench & Co.           South Asian
# ..                          ...                   ...
# 64             Dutton & Company           South Asian
# 10                          NaN           South Asian
# 51                          NaN               British
# 100           Macmillan Company           South Asian
# 34         P.F. Vollard Company              American
#
#                                            Keywords      Origin  \
# 2                 Introduction by Francis H. Skrine   Gutenberg
# 14                                              NaN  HathiTrust
# 32                    Ethnography; Literary Quality   Gutenberg
# 17                                              NaN   Gutenberg
# 30                       Preface by Edmund W. Gosse   Gutenberg
# ..                                              ...         ...
# 64                                 Juvenile Fiction   Gutenberg
# 10   Translation; Translated by Dakshina Charan Roy  HathiTrust
# 51                                 Juvenile fiction   Gutenberg
# 100  Translated from Bengali by Devabrata Mukherjee   Gutenberg
# 34                                 Juvenile Fiction   Gutenberg
#
#      Overall Types  Overall Tokens  Overall TTR  Standardized Types  \
# 2             6797           46332    14.670206                1667
# 14            9971          105895     9.415931                1550
# 32            6234           30912    20.166925                1529
# 17            9344          119562     7.815192                1520
# 30            4326           22740    19.023747                1504
# ..             ...             ...          ...                 ...
# 64            2452           19911    12.314801                 908
# 10            3670           37776     9.715163                 901
# 51            2905           30540     9.512115                 895
# 100           1191            7674    15.519937                 785
# 34            1887           17775    10.616034                 709
#
#      Standardized Tokens  Standardized TTR
# 2                   4051         41.150333
# 14                  4051         38.262157
# 32                  4051         37.743767
# 17                  4051         37.521600
# 30                  4051         37.126635
# ..                   ...               ...
# 64                  4051         22.414219
# 10                  4051         22.241422
# 51                  4051         22.093310
# 100                 4051         19.377931
# 34                  4051         17.501851
#
# [110 rows x 17 columns]

# %% [markdown]
# # Using GroupBy and Mean to Get Our TTR-by-Nationality Data
#
# Now that we have this mega-DataFrame — it contains all the CSAL metadata, and all our precious TTR data — we can pursue our original research question: do texts written by authors from the subcontinent have higher or lower TTRs than texts written by authors identified as foreign?
#
# **What data do we actually need to see, in what format, to pursue that research question?**
#
# Let's start by using our old friend `df.groupby()` and group this DataFrame by the `Nationality of Author` column.

# %%
csal_by_nationality_df = csal_ttr_df.groupby('Nationality of Author')
csal_by_nationality_df

# %% [markdown]
# DataFrames produced by GroupBy can't be visualized in the standard way that normal DataFrames are. We need to call methods on them to see what's inside. Remember what we're looking for: the **mean standardized TTR for each category of author nationality**. If we just call on old reliable `df.describe()`, we can see that this data is already the `csal_by_nationality_df` DataFrame we just produced. Do you see where it is in the below output?

# %%
csal_by_nationality_df.describe()
# Out:
#                        Year                                                   \
#                       count         mean        std     min      25%     50%
# Nationality of Author
# American               13.0  1918.923077  10.820209  1900.0  1914.00  1916.0
# British                51.0  1899.705882  15.386090  1855.0  1893.50  1900.0
# British, American       1.0  1892.000000        NaN  1892.0  1892.00  1892.0
# Canadian                5.0  1899.600000   7.021396  1893.0  1894.00  1898.0
# Irish                   3.0  1893.666667  15.307950  1882.0  1885.00  1888.0
# South Asian            35.0  1905.257143  25.186765  1828.0  1898.50  1916.0
# South Asian; British    2.0  1906.500000  17.677670  1894.0  1900.25  1906.5
#
#                                        Original (if translated)               \
#                            75%     max                    count         mean
# Nationality of Author
# American               1927.00  1937.0                      0.0          NaN
# British                1911.00  1924.0                      0.0          NaN
# British, American      1892.00  1892.0                      0.0          NaN
# Canadian               1903.00  1910.0                      0.0          NaN
# Irish                  1899.50  1911.0                      0.0          NaN
# South Asian            1918.50  1941.0                     14.0  1891.928571
# South Asian; British   1912.75  1919.0                      0.0          NaN
#
#                        ... Standardized Tokens         Standardized TTR  \
#                        ...                 75%     max            count
# Nationality of Author  ...
# American               ...              4051.0  4051.0             13.0
# British                ...              4051.0  4051.0             51.0
# British, American      ...              4051.0  4051.0              1.0
# Canadian               ...              4051.0  4051.0              5.0
# Irish                  ...              4051.0  4051.0              3.0
# South Asian            ...              4051.0  4051.0             35.0
# South Asian; British   ...              4051.0  4051.0              2.0
#
#                                                                              \
#                             mean       std        min        25%        50%
# Nationality of Author
# American               31.086341  5.031712  17.501851  29.227351  30.856579
# British                31.393846  3.945915  22.093310  28.894100  32.214268
# British, American      28.980499       NaN  28.980499  28.980499  28.980499
# Canadian               30.244384  1.849369  27.622809  29.869168  29.992594
# Irish                  36.846869  1.372273  35.522093  36.139225  36.756356
# South Asian            30.201361  4.516893  19.377931  28.610220  30.585041
# South Asian; British   33.929894  0.401468  33.646013  33.787954  33.929894
#
#
#                              75%        max
# Nationality of Author
# American               33.349790  36.929153
# British                34.102691  37.743767
# British, American      28.980499  28.980499
# Canadian               31.054061  32.683288
# Irish                  37.509257  38.262157
# South Asian            32.843742  41.150333
# South Asian; British   34.071834  34.213774
#
# [7 rows x 64 columns]

# %% [markdown]
# Here's how we grab only the information we want from `csal_by_nationality_df` — subsetting to the `Standardized TTR` column (using a method we've been using for a few weeks now — passing a `['list containing a single string']` into the `dataframe[ ]` structure) and then calling the Pandas `.mean()` function on that column.
#
# What we get from this is just a plain old Pandas DataFrame (not a GroupBy object)

# %%
csal_by_nationality_df[['Standardized TTR']].mean()
# Out:
#                        Standardized TTR
# Nationality of Author
# American                      31.086341
# British                       31.393846
# British, American             28.980499
# Canadian                      30.244384
# Irish                         36.846869
# South Asian                   30.201361
# South Asian; British          33.929894

# %%
type(csal_by_nationality_df[['Standardized TTR']].mean())
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Now let's stick that into a variable... and let's make a plot of the data we've uncovered... and then interpret the results together!

# %%
mean_ttr_by_nationality_df = csal_by_nationality_df[['Standardized TTR']].mean()

# %%
mean_ttr_by_nationality_df.plot(kind='bar', figsize=(10,5), title='Standardized TTRs Averaged Across Nationality of Author')
# Out:
# <Axes: title={'center': 'Standardized TTRs Averaged Across Nationality of Author'}, xlabel='Nationality of Author'>

# %% [markdown]
# Let's now look at similar plots for TTR data sorted according to different metadata categories, using the same methods employed above. Does this give you any further insight into the results above?

# %%
csal_ttr_by_year_df = csal_ttr_df.groupby('Year')
mean_ttr_by_year_df = csal_ttr_by_year_df[['Standardized TTR']].mean()
mean_ttr_by_year_df
# Out:
#       Standardized TTR
# Year
# 1828         29.153295
# 1829         34.435942
# 1855         28.881758
# 1859         30.140706
# 1860         33.670699
# 1870         33.596643
# 1873         29.252037
# 1877         31.300913
# 1879         25.475191
# 1881         30.066650
# 1882         38.262157
# 1884         33.720069
# 1885         35.596149
# 1887         36.312022
# 1888         32.646260
# 1890         32.140212
# 1892         28.980499
# 1893         31.658850
# 1894         29.223237
# 1895         27.240188
# 1896         32.596890
# 1897         35.028388
# 1898         30.696124
# 1900         32.436435
# 1901         31.091089
# 1902         22.093310
# 1903         30.905949
# 1904         32.329466
# 1905         27.524068
# 1906         25.697359
# 1908         33.234592
# 1909         34.806221
# 1910         34.250802
# 1911         34.403028
# 1912         33.300420
# 1913         28.717189
# 1914         26.055295
# 1915         27.902575
# 1916         30.371102
# 1917         32.234839
# 1918         27.005678
# 1919         31.893360
# 1920         31.004690
# 1921         31.177487
# 1922         29.976138
# 1923         27.178474
# 1924         32.107299
# 1927         36.657615
# 1929         17.501851
# 1932         32.164898
# 1935         30.140706
# 1937         36.929153
# 1941         33.226364

# %%
mean_ttr_by_year_df.plot(figsize=(15,5), title='Standardized TTRs Averaged Across Year of Publication')
# Out:
# <Axes: title={'center': 'Standardized TTRs Averaged Across Year of Publication'}, xlabel='Year'>

# %%
mean_ttr_by_genre_df = csal_ttr_df.groupby('Genre')[['Standardized TTR']].mean()
mean_ttr_by_genre_df
# Out:
#             Standardized TTR
# Genre
# Drama              24.759319
# Fiction            30.818375
# Nonfiction         33.312762
# Poetry             31.621822

# %%
mean_ttr_by_genre_df.plot(kind='bar', figsize=(10,5), title='Standardized TTRs Averaged Across Genre of Text')
# Out:
# <AxesSubplot:title={'center':'Standardized TTRs Averaged Across Genre of Text'}, xlabel='Genre'>

# %% [markdown]
# Let's use the techniques we learned last time to produce our gender signal-by-year plots to see exactly how many works in each Genre appear for each of the author nationalities.

# %%
csal_ttr_df.groupby(['Genre', 'Nationality of Author']).size()
# Out:
# Genre       Nationality of Author
# Drama       South Asian               2
# Fiction     American                 11
#             British                  43
#             British, American         1
#             Canadian                  5
#             Irish                     3
#             South Asian              20
#             South Asian; British      1
# Nonfiction  American                  2
#             British                   7
#             South Asian               5
# Poetry      British                   1
#             South Asian               8
#             South Asian; British      1
# dtype: int64

# %%
csal_ttr_df.groupby(['Genre', 'Nationality of Author']).size().unstack()
# Out:
# Nationality of Author  American  British  British, American  Canadian  Irish  \
# Genre
# Drama                       NaN      NaN                NaN       NaN    NaN
# Fiction                    11.0     43.0                1.0       5.0    3.0
# Nonfiction                  2.0      7.0                NaN       NaN    NaN
# Poetry                      NaN      1.0                NaN       NaN    NaN
#
# Nationality of Author  South Asian  South Asian; British
# Genre
# Drama                          2.0                   NaN
# Fiction                       20.0                   1.0
# Nonfiction                     5.0                   NaN
# Poetry                         8.0                   1.0

# %%
csal_genre_by_nationality_df = csal_ttr_df.groupby(['Genre', 'Nationality of Author']).size().unstack(fill_value=0)
csal_genre_by_nationality_df
# Out:
# Nationality of Author  American  British  British, American  Canadian  Irish  \
# Genre
# Drama                         0        0                  0         0      0
# Fiction                      11       43                  1         5      3
# Nonfiction                    2        7                  0         0      0
# Poetry                        0        1                  0         0      0
#
# Nationality of Author  South Asian  South Asian; British
# Genre
# Drama                            2                     0
# Fiction                         20                     1
# Nonfiction                       5                     0
# Poetry                           8                     1

# %%
csal_genre_by_nationality_df = csal_ttr_df.groupby(['Genre', 'Nationality of Author'])[['Standardized TTR']].mean().unstack(fill_value=0)
csal_genre_by_nationality_df
# Out:
#                       Standardized TTR                               \
# Nationality of Author         American    British British, American
# Genre
# Drama                         0.000000   0.000000          0.000000
# Fiction                      30.742129  30.740041         28.980499
# Nonfiction                   32.979511  34.707480          0.000000
# Poetry                        0.000000  36.312022          0.000000
#
#
# Nationality of Author   Canadian      Irish South Asian South Asian; British
# Genre
# Drama                   0.000000   0.000000   24.759319             0.000000
# Fiction                30.244384  36.846869   30.190077            34.213774
# Nonfiction              0.000000   0.000000   31.493458             0.000000
# Poetry                  0.000000   0.000000   30.782523            33.646013

# %%
csal_genre_by_nationality_df.plot(kind='bar', figsize=(10,5), title='Standardized TTRs Averaged Across Genre of Text and Nationality of Author').legend(loc="lower right")

# %% [markdown]
# Note that things are lumped by rows: drama, fiction, etc.  What if we'd wanted things to be lumped by nationality?  We could create a new dataframe `csal_ttr_df.groupby(['Nationality of Author','Genre', ]).size().unstack(fill_value=0)` by exchanging the order of `Nationality of Author` and `Genre`

# %%
csal_ttr_df.groupby(['Nationality of Author','Genre', ])[['Standardized TTR']].mean().unstack(fill_value=0)
# Out:
#                       Standardized TTR
# Genre                            Drama    Fiction Nonfiction     Poetry
# Nationality of Author
# American                      0.000000  30.742129  32.979511   0.000000
# British                       0.000000  30.740041  34.707480  36.312022
# British, American             0.000000  28.980499   0.000000   0.000000
# Canadian                      0.000000  30.244384   0.000000   0.000000
# Irish                         0.000000  36.846869   0.000000   0.000000
# South Asian                  24.759319  30.190077  31.493458  30.782523
# South Asian; British          0.000000  34.213774   0.000000  33.646013

# %% [markdown]
# Or we can use pandas' transpose command `csal_genre_by_nationality_df.T`

# %%
csal_genre_by_nationality_df.T
# Out:
# Genre                                       Drama    Fiction  Nonfiction  \
#                  Nationality of Author
# Standardized TTR American                0.000000  30.742129   32.979511
#                  British                 0.000000  30.740041   34.707480
#                  British, American       0.000000  28.980499    0.000000
#                  Canadian                0.000000  30.244384    0.000000
#                  Irish                   0.000000  36.846869    0.000000
#                  South Asian            24.759319  30.190077   31.493458
#                  South Asian; British    0.000000  34.213774    0.000000
#
# Genre                                      Poetry
#                  Nationality of Author
# Standardized TTR American                0.000000
#                  British                36.312022
#                  British, American       0.000000
#                  Canadian                0.000000
#                  Irish                   0.000000
#                  South Asian            30.782523
#                  South Asian; British   33.646013

# %% [markdown]
# And we can plot if we want!

# %%
ax = csal_genre_by_nationality_df.T.plot(kind='bar', figsize=(10,5), title='Standardized TTRs Averaged Across Genre of Text and Nationality of Author', xlabel='Nationality of Author', ylabel='Standardized TTR')
ax.set_xticklabels(['American', 'Britsh', 'British, American', 'Canadian', 'Irish', 'South Asian', 'South Asian; British'])
# Out:
# [Text(0, 0, 'American'),
#  Text(1, 0, 'Britsh'),
#  Text(2, 0, 'British, American'),
#  Text(3, 0, 'Canadian'),
#  Text(4, 0, 'Irish'),
#  Text(5, 0, 'South Asian'),
#  Text(6, 0, 'South Asian; British')]

# %% [markdown]
# Let's close today's class by
#
# - imagining how we could improve our approach to our original research question
# - thinking of what other research questions we could ask of the CSAL dataset — with the TTR data we've added, or perhaps with some other metadata category or textual metric?
