# %% [markdown]
# # Week 11 Homework
#
# ## Instructions
# For each task, write your code in the cell below the comment. (Unlike in labs, there are no per-task tests provided, though you can write your own small tests as you go.) When all of the code is complete, upload it to Markus.
#
# ## Due date
# This homework is due **Friday Nov 29th at 10pm**

# %% [markdown]
# Import data on our sentiment battle: comparing two sentiment systems on 8 categories of tricky sentences

# %%
import pandas as pd
battle_data = pd.read_csv("sentiment_battle.csv")
battle_data.head()
# Out:
#    Unnamed: 0                                               text category  \
# 0           0  Oh great, another meeting that could've been a...  sarcasm
# 1           1                    Well isn't this just perfect...  sarcasm
# 2           2  How wonderful to spend my Sunday fixing someon...  sarcasm
# 3           3                                 Thanks for nothing  sarcasm
# 4           4                               You're so helpful /s  sarcasm
#
#    textblob_score textblob_sentiment  vader_score vader_sentiment  \
# 0             1.0           positive       0.6588        positive
# 1             1.0           positive       0.2732        positive
# 2             1.0           positive       0.2960        positive
# 3             0.2           positive       0.4404        positive
# 4             0.0            neutral       0.4754        positive
#
#    sentiment_mismatch
# 0               False
# 1               False
# 2               False
# 3               False
# ...

# %% [markdown]
# Use the code below to look at the list of categories we have...

# %%
print(battle_data["category"].unique())
# Out:
# ['sarcasm' 'intensifiers' 'negations' 'context_dependent'
#  'mixed_sentiment' 'emoji_slang' 'subtle_implications' 'complex_emotions']

# %% [markdown]
# show all lines for the paricular category

# %%
battle_data[battle_data["category"] == "sarcasm"]
# Out:
#    Unnamed: 0                                               text category  \
# 0           0  Oh great, another meeting that could've been a...  sarcasm
# 1           1                    Well isn't this just perfect...  sarcasm
# 2           2  How wonderful to spend my Sunday fixing someon...  sarcasm
# 3           3                                 Thanks for nothing  sarcasm
# 4           4                               You're so helpful /s  sarcasm
# 5           5  Absolutely thrilled to be stuck in traffic rig...  sarcasm
# 6           6       My favorite part was when the system crashed  sarcasm
#
#    textblob_score textblob_sentiment  vader_score vader_sentiment  \
# 0        1.000000           positive       0.6588        positive
# 1        1.000000           positive       0.2732        positive
# 2        1.000000           positive       0.2960        positive
# 3        0.200000           positive       0.4404        positive
# ...

# %% [markdown]
# or print all sentences in that category

# %%
battle_data[battle_data["category"] == "sarcasm"]["text"].to_list()
# Out:
# ["Oh great, another meeting that could've been an email!",
#  "Well isn't this just perfect...",
#  "How wonderful to spend my Sunday fixing someone else's mistakes",
#  'Thanks for nothing',
#  "You're so helpful /s",
#  'Absolutely thrilled to be stuck in traffic right now',
#  'My favorite part was when the system crashed']

# %% [markdown]
# ## Task 1.
# Group `battle_data` by category and calculate `mean` for `vader_score`. Sort so that the most positive category would go first. Assign the resulting dataframe to `battle_data_groupped`

# %%
battle_data_groupped = ...

# %% [markdown]
# create an `str` variable `vader_nagative` containing the name of the  category with the most negative polarity

# %%
vader_negative = ...

# %% [markdown]
# ## Task 2.
# Assign a `list` of all sentences in that category to a variable `negative_category_sentences`

# %%
negative_category_sentences = ...

# %% [markdown]
# ## Task 3: Load a "Chunked" Version of James Joyce's *Portrait of the Artist as a Young Man*
#
# In the same folder as this notebook, there is a file named `portrait_chunks.csv` which contains two columns and 85 rows:
# - the `chunk` column contains sequential 1000-word chunks from James Joyce's novel *A Portrait of the Artist as a Young Man*
# - the `ttr` column contains the TTR for the 1000-word chunk in its row.
#
# Import Pandas as `pd` and read `portrait_chunks.csv` into a Pandas DataFrame named `portrait_chunks_df`.

# %%
# Write your code here

# %% [markdown]
# # Task 4: Calculate Rolling Average Columns for 6-chunk Windows
#
# Add a column `rolling_6_ttr` to `portrait_chunks_df`. It should contain rolling average TTR values with window size 6 and should use the `center=True` paramater.

# %%
# Write your code here

# %% [markdown]
# # Task 5: Find the Minimum and Maximum Values of the `rolling_6_ttr` Column
#
# Store the minimum and maximum **values** (not number of the chunk that contains the minimum and maximum values, not the text of the chunk that contains the minimum and maximum values, but the actual minimum and maximum **values**). Store them in variables named:
# - `rolling_6_ttr_min`
# - `rolling_6_ttr_max`

# %%
# Write your code here

# %% [markdown]
# ## Marking Rubric
# This assignment will be partially graded manually.
#
# For the autotested part your mark fully determined by the "correctness" of the code as measured by the autograder. For example, if it says that 60% of the tests passed successfully, your mark on the autotested part will be 60%.
#
# ## How to Submit
# 1. Download your homework to your local computer and save it as `W11_hw.ipynb`.
# 2. Log into MarkUs using the link on Quercus.
# 3. Submit your homework to `hw11: Homework 11`.
